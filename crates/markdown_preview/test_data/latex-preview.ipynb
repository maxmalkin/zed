# %% [markdown]
# # Markdown cell math
# Inline $\mathbb{R}$ and display:
# $$\frac{1}{2}$$

# %%
from IPython.display import Latex, display
display(Latex(r"\frac{1}{2}+\mathbb{R}"))

# %%
# Configure previewlocal in latex.preamble and latex.package_directory first.
display(Latex(r"\text{\previewlocalmessage}"))
